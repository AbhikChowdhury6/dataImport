# %%
import os
import sys
def getRepoPath():
    cwd = os.getcwd()
    delimiter = "\\" if "\\" in cwd else "/"
    repoPath = delimiter.join(cwd.split(delimiter)[:cwd.split(delimiter).index("dataImport")]) + delimiter
    return repoPath
repoPath = getRepoPath()
sys.path.append(repoPath + 'dataImport/')
from utils import workingDataPath, getWorkingHRDfParquet, getHRGroups

import pandas as pd
import matplotlib.pyplot as plt


AppleWatchHRDf = getWorkingHRDfParquet('apple')

# %%
ax = AppleWatchHRDf.value.plot.hist(bins=[x for x in range(40,200)], title="Overall BPM Counts")
ax.set_xlabel("BPM")
# Out:
# Text(0.5, 0, 'BPM')

# %%
#output cols HR seconds
def timeBalancedHRHist(HRDf, maxInterval):
    #get min and max HR
    minHR = 30
    maxHR = 210
    # HRDF
    HRDfCopy = HRDf.copy()
    # calc between measures
    timeSeries = pd.Series(HRDf.index)
    bm = pd.Series(index=HRDf.index, data = (timeSeries.shift(-1) - timeSeries).dt.total_seconds().values)
    HRDfCopy['betweenMeasures'] = bm
    # the last value will be nan so replace it with the max interval
    HRDfCopy['betweenMeasures'] = HRDfCopy['betweenMeasures'].fillna(maxInterval)
    # if above thershold set to max
    HRDfCopy[HRDfCopy['betweenMeasures'] > maxInterval] = maxInterval
    
    data = []
    # for every heartrate in the range
    for hr in range(minHR, maxHR + 1):
        # sum the thersholded between measures
        totalTime = HRDfCopy[HRDfCopy['value'] == hr].betweenMeasures.sum()
        data.append([hr, totalTime])
        # if hr == 140:
            # print(f"number of samples for {hr} is {len(HRDfCopy[HRDfCopy['value'] == hr])}")
            # print(f"the average between measures is {HRDfCopy[HRDfCopy['value'] == hr].betweenMeasures.mean()}")
    return pd.DataFrame(data=data, columns=['hr', 'seconds'])

# %%
import matplotlib.pyplot as plt
tbDF = timeBalancedHRHist(AppleWatchHRDf, 300)
tbDF.plot(kind='bar', y='seconds', x='hr', figsize=(10,6), linewidth=0.0,width=1)
plt.xticks(ticks=range(0, len(tbDF), 10), labels=tbDF['hr'][::10])
# Show the plot
plt.tight_layout()
plt.show()

# %%
tbDF
# Out:
#       hr  seconds
# 0     38    300.0
# 1     39      0.0
# 2     40    300.0
# 3     41    300.0
# 4     42   2100.0
# ..   ...      ...
# 156  194      0.0
# 157  195      0.0
# 158  196      0.0
# 159  197    300.0
# 160  198    300.0
#
# [161 rows x 2 columns]

# %%
AppleWatchHRDf
# Out:
#                            value
# sampleDT
# 2021-07-19 19:55:06-07:00   78.0
# 2021-07-19 19:55:11-07:00   79.0
# 2021-07-19 19:55:14-07:00   80.0
# 2021-07-19 19:55:21-07:00   82.0
# 2021-07-19 19:55:23-07:00   83.0
# ...                          ...
# 2024-09-17 12:53:00-07:00   70.0
# 2024-09-17 12:53:07-07:00   70.0
# 2024-09-17 12:53:14-07:00   72.0
# 2024-09-17 12:53:17-07:00   73.0
# 2024-09-17 12:53:24-07:00   75.0
#
# [567895 rows x 1 columns]

# %%
AppleWatchHRDf = AppleWatchHRDf.sort_index()

# %%
timesSeries = pd.Series(AppleWatchHRDf.index)

# %%
betweenMesures = ((timesSeries.shift(-1) - timesSeries)).astype('timedelta64[s]')

# %%
betweenMesures
# Out:
# 0        0 days 00:00:05
# 1        0 days 00:00:03
# 2        0 days 00:00:07
# 3        0 days 00:00:02
# 4        0 days 00:00:07
#                ...
# 567890   0 days 00:00:07
# 567891   0 days 00:00:07
# 567892   0 days 00:00:03
# 567893   0 days 00:00:07
# 567894               NaT
# Name: sampleDT, Length: 567895, dtype: timedelta64[s]

# %%
AppleWatchHRDf["timeToNextReading"] = pd.Series(index=AppleWatchHRDf.index, data=betweenMesures.values)

# %%
betweenMesures = betweenMesures.dropna()

# %%
AppleWatchHRDf = AppleWatchHRDf.dropna()

# %%
AppleWatchHRDf
# Out:
#                            value timeToNextReading
# sampleDT
# 2021-07-19 19:55:06-07:00   78.0   0 days 00:00:05
# 2021-07-19 19:55:11-07:00   79.0   0 days 00:00:03
# 2021-07-19 19:55:14-07:00   80.0   0 days 00:00:07
# 2021-07-19 19:55:21-07:00   82.0   0 days 00:00:02
# 2021-07-19 19:55:23-07:00   83.0   0 days 00:00:07
# ...                          ...               ...
# 2024-09-17 12:52:58-07:00   69.0   0 days 00:00:02
# 2024-09-17 12:53:00-07:00   70.0   0 days 00:00:07
# 2024-09-17 12:53:07-07:00   70.0   0 days 00:00:07
# 2024-09-17 12:53:14-07:00   72.0   0 days 00:00:03
# 2024-09-17 12:53:17-07:00   73.0   0 days 00:00:07
#
# [567894 rows x 2 columns]

# %%
betweenMesures = betweenMesures.sort_values()

# %%
betweenMesures = betweenMesures.dt.total_seconds()

# %%
ax = betweenMesures.plot.hist(bins=100, log=True, title="All Intervals Between Readings (Log Scale)")
ax.set_xlabel("Interval (sec)")
# Out:
# Text(0.5, 0, 'Interval (sec)')

# %%
ax = betweenMesures.loc[betweenMesures<660].plot.hist(bins=659, log=True, title="Intervals Less Than 11 Minutes (Log Scale)")
ax.set_xlabel("Interval (sec)")
ax.axvline(600, color='k', linestyle='dashed', linewidth=1)

# %%
ax = betweenMesures.loc[betweenMesures<660].plot.hist(bins=659, title="Intervals Less Than 11 Minutes (Linear Scale)")
ax.set_xlabel("Interval (sec)")
ax.axvline(600, color='k', linestyle='dashed', linewidth=1)

# %%
ax = betweenMesures.loc[betweenMesures<660].loc[betweenMesures>10].plot.hist(bins=648, title="Intervals Between 10 seconds and 11 Minutes (Linear Scale)")
ax.set_xlabel("Interval (sec)")
ax.axvline(10, color='k', linestyle='dashed', linewidth=1)
ax.axvline(600, color='k', linestyle='dashed', linewidth=1)

# %%
ax = betweenMesures.loc[betweenMesures<20].plot.hist(bins=19, title="Intervals Less Than 20 Seconds (Linear Scale)")
ax.set_xlabel("Interval (sec)")
ax.axvline(10, color='k', linestyle='dashed', linewidth=1)

# %%
betweenMesures.describe()
# Out:
# count    3.713570e+05
# mean     2.640582e+02
# std      4.355975e+03
# min      1.000000e+00
# 25%      6.000000e+00
# 50%      1.630000e+02
# 75%      3.170000e+02
# max      1.242634e+06
# Name: sampleDT, dtype: float64

# %%
AppleWatchHRDf[AppleWatchHRDf["timeToNextReading"] < 10].value.describe()
# Out:
# count    128662.000000
# mean        101.450251
# std          26.735434
# min          42.000000
# 25%          84.000000
# 50%          95.000000
# 75%         110.000000
# max         198.000000
# Name: value, dtype: float64

# %%
workOutBPMdf = AppleWatchHRDf[AppleWatchHRDf["timeToNextReading"] < 10]
ax = workOutBPMdf.value.plot.hist(bins=20, xlim=(40,200), title="BPM for Intervals Less Than 10 Seconds")
ax.set_xlabel("BPM")
ax.axvline(AppleWatchHRDf[AppleWatchHRDf["timeToNextReading"] < 10].value.mean(), color='k', linestyle='dashed', linewidth=1)

# %%
standByBPMdf = AppleWatchHRDf.loc[(AppleWatchHRDf["timeToNextReading"] >= 10) &
                        (AppleWatchHRDf["timeToNextReading"] < 600)]

ax = standByBPMdf.value.plot.hist(bins=20, xlim=(40,200), title="BPM for Intervals Between 10 Seconds and 10 Minutes")
ax.set_xlabel("BPM")
ax.axvline(standByBPMdf.value.mean(), color='k', linestyle='dashed', linewidth=1)

# %%
# plt.hist()
ax = standByBPMdf.value.plot.hist(bins=[x for x in range(30,221, (220-30)//40)], xlim=(30,200), alpha=0.5, label="10-600 Sec", title="BPM for Low and Medium Intervals")
ax.hist(workOutBPMdf.value, bins=[x for x in range(30,221, (220-30)//40)], alpha=0.5, color="g", label="<10 Sec")
ax.set_xlabel("BPM")
ax.axvline(standByBPMdf.value.mean(), color='b', linestyle='dashed', linewidth=1)
ax.axvline(workOutBPMdf.value.mean(), color='darkgreen', linestyle='dashed', linewidth=1)
ax.legend(loc='upper right') 
ax.set_xlim(30,220)
# Out:
# (30.0, 220.0)

# %%
from collections import OrderedDict
minGroupTime = pd.Timedelta(seconds=1)

dataod = OrderedDict()
for maxDelta in range(1,800+1):
    hrGroups = getHRGroups(AppleWatchHRDf, maxDelta, minGroupTime)
    hrGroupDurations = [(g[1]-g[0]).total_seconds() for g in hrGroups]
    dataod[maxDelta] = hrGroupDurations
    print(f"generated {len(dataod)} groups")
# Out:
# generated 1 groups
# generated 2 groups
# generated 3 groups
# generated 4 groups
# generated 5 groups
# generated 6 groups
# generated 7 groups
# generated 8 groups
# generated 9 groups
# generated 10 groups
# generated 11 groups
# generated 12 groups
# generated 13 groups
# generated 14 groups
# generated 15 groups
# generated 16 groups
# generated 17 groups
# generated 18 groups
# generated 19 groups
# generated 20 groups
# generated 21 groups
# generated 22 groups
# generated 23 groups
# generated 24 groups
# generated 25 groups
# generated 26 groups
# generated 27 groups
# generated 28 groups
# generated 29 groups
# generated 30 groups
# generated 31 groups
# generated 32 groups
# generated 33 groups
# generated 34 groups
# generated 35 groups
# generated 36 groups
# generated 37 groups
# generated 38 groups
# generated 39 groups
# generated 40 groups
# generated 41 groups
# generated 42 groups
# generated 43 groups
# generated 44 groups
# generated 45 groups
# generated 46 groups
# generated 47 groups
# generated 48 groups
# generated 49 groups
# generated 50 groups
# generated 51 groups
# generated 52 groups
# generated 53 groups
# generated 54 groups
# generated 55 groups
# generated 56 groups
# generated 57 groups
# generated 58 groups
# generated 59 groups
# generated 60 groups
# generated 61 groups
# generated 62 groups
# generated 63 groups
# generated 64 groups
# generated 65 groups
# generated 66 groups
# generated 67 groups
# generated 68 groups
# generated 69 groups
# generated 70 groups
# generated 71 groups
# generated 72 groups
# generated 73 groups
# generated 74 groups
# generated 75 groups
# generated 76 groups
# generated 77 groups
# generated 78 groups
# generated 79 groups
# generated 80 groups
# generated 81 groups
# generated 82 groups
# generated 83 groups
# generated 84 groups
# generated 85 groups
# generated 86 groups
# generated 87 groups
# generated 88 groups
# generated 89 groups
# generated 90 groups
# generated 91 groups
# generated 92 groups
# generated 93 groups
# generated 94 groups
# generated 95 groups
# generated 96 groups
# generated 97 groups
# generated 98 groups
# generated 99 groups
# generated 100 groups
# generated 101 groups
# generated 102 groups
# generated 103 groups
# generated 104 groups
# generated 105 groups
# generated 106 groups
# generated 107 groups
# generated 108 groups
# generated 109 groups
# generated 110 groups
# generated 111 groups
# generated 112 groups
# generated 113 groups
# generated 114 groups
# generated 115 groups
# generated 116 groups
# generated 117 groups
# generated 118 groups
# generated 119 groups
# generated 120 groups
# generated 121 groups
# generated 122 groups
# generated 123 groups
# generated 124 groups
# generated 125 groups
# generated 126 groups
# generated 127 groups
# generated 128 groups
# generated 129 groups
# generated 130 groups
# generated 131 groups
# generated 132 groups
# generated 133 groups
# generated 134 groups
# generated 135 groups
# generated 136 groups
# generated 137 groups
# generated 138 groups
# generated 139 groups
# generated 140 groups
# generated 141 groups
# generated 142 groups
# generated 143 groups
# generated 144 groups
# generated 145 groups
# generated 146 groups
# generated 147 groups
# generated 148 groups
# generated 149 groups
# generated 150 groups
# generated 151 groups
# generated 152 groups
# generated 153 groups
# generated 154 groups
# generated 155 groups
# generated 156 groups
# generated 157 groups
# generated 158 groups
# generated 159 groups
# generated 160 groups
# generated 161 groups
# generated 162 groups
# generated 163 groups
# generated 164 groups
# generated 165 groups
# generated 166 groups
# generated 167 groups
# generated 168 groups
# generated 169 groups
# generated 170 groups
# generated 171 groups
# generated 172 groups
# generated 173 groups
# generated 174 groups
# generated 175 groups
# generated 176 groups
# generated 177 groups
# generated 178 groups
# generated 179 groups
# generated 180 groups
# generated 181 groups
# generated 182 groups
# generated 183 groups
# generated 184 groups
# generated 185 groups
# generated 186 groups
# generated 187 groups
# generated 188 groups
# generated 189 groups
# generated 190 groups
# generated 191 groups
# generated 192 groups
# generated 193 groups
# generated 194 groups
# generated 195 groups
# generated 196 groups
# generated 197 groups
# generated 198 groups
# generated 199 groups
# generated 200 groups
# generated 201 groups
# generated 202 groups
# generated 203 groups
# generated 204 groups
# generated 205 groups
# generated 206 groups
# generated 207 groups
# generated 208 groups
# generated 209 groups
# generated 210 groups
# generated 211 groups
# generated 212 groups
# generated 213 groups
# generated 214 groups
# generated 215 groups
# generated 216 groups
# generated 217 groups
# generated 218 groups
# generated 219 groups
# generated 220 groups
# generated 221 groups
# generated 222 groups
# generated 223 groups
# generated 224 groups
# generated 225 groups
# generated 226 groups
# generated 227 groups
# generated 228 groups
# generated 229 groups
# generated 230 groups
# generated 231 groups
# generated 232 groups
# generated 233 groups
# generated 234 groups
# generated 235 groups
# generated 236 groups
# generated 237 groups
# generated 238 groups
# generated 239 groups
# generated 240 groups
# generated 241 groups
# generated 242 groups
# generated 243 groups
# generated 244 groups
# generated 245 groups
# generated 246 groups
# generated 247 groups
# generated 248 groups
# generated 249 groups
# generated 250 groups
# generated 251 groups
# generated 252 groups
# generated 253 groups
# generated 254 groups
# generated 255 groups
# generated 256 groups
# generated 257 groups
# generated 258 groups
# generated 259 groups
# generated 260 groups
# generated 261 groups
# generated 262 groups
# generated 263 groups
# generated 264 groups
# generated 265 groups
# generated 266 groups
# generated 267 groups
# generated 268 groups
# generated 269 groups
# generated 270 groups
# generated 271 groups
# generated 272 groups
# generated 273 groups
# generated 274 groups
# generated 275 groups
# generated 276 groups
# generated 277 groups
# generated 278 groups
# generated 279 groups
# generated 280 groups
# generated 281 groups
# generated 282 groups
# generated 283 groups
# generated 284 groups
# generated 285 groups
# generated 286 groups
# generated 287 groups
# generated 288 groups
# generated 289 groups
# generated 290 groups
# generated 291 groups
# generated 292 groups
# generated 293 groups
# generated 294 groups
# generated 295 groups
# generated 296 groups
# generated 297 groups
# generated 298 groups
# generated 299 groups
# generated 300 groups
# generated 301 groups
# generated 302 groups
# generated 303 groups
# generated 304 groups
# generated 305 groups
# generated 306 groups
# generated 307 groups
# generated 308 groups
# generated 309 groups
# generated 310 groups
# generated 311 groups
# generated 312 groups
# generated 313 groups
# generated 314 groups
# generated 315 groups
# generated 316 groups
# generated 317 groups
# generated 318 groups
# generated 319 groups
# generated 320 groups
# generated 321 groups
# generated 322 groups
# generated 323 groups
# generated 324 groups
# generated 325 groups
# generated 326 groups
# generated 327 groups
# generated 328 groups
# generated 329 groups
# generated 330 groups
# generated 331 groups
# generated 332 groups
# generated 333 groups
# generated 334 groups
# generated 335 groups
# generated 336 groups
# generated 337 groups
# generated 338 groups
# generated 339 groups
# generated 340 groups
# generated 341 groups
# generated 342 groups
# generated 343 groups
# generated 344 groups
# generated 345 groups
# generated 346 groups
# generated 347 groups
# generated 348 groups
# generated 349 groups
# generated 350 groups
# generated 351 groups
# generated 352 groups
# generated 353 groups
# generated 354 groups
# generated 355 groups
# generated 356 groups
# generated 357 groups
# generated 358 groups
# generated 359 groups
# generated 360 groups
# generated 361 groups
# generated 362 groups
# generated 363 groups
# generated 364 groups
# generated 365 groups
# generated 366 groups
# generated 367 groups
# generated 368 groups
# generated 369 groups
# generated 370 groups
# generated 371 groups
# generated 372 groups
# generated 373 groups
# generated 374 groups
# generated 375 groups
# generated 376 groups
# generated 377 groups
# generated 378 groups
# generated 379 groups
# generated 380 groups
# generated 381 groups
# generated 382 groups
# generated 383 groups
# generated 384 groups
# generated 385 groups
# generated 386 groups
# generated 387 groups
# generated 388 groups
# generated 389 groups
# generated 390 groups
# generated 391 groups
# generated 392 groups
# generated 393 groups
# generated 394 groups
# generated 395 groups
# generated 396 groups
# generated 397 groups
# generated 398 groups
# generated 399 groups
# generated 400 groups
# generated 401 groups
# generated 402 groups
# generated 403 groups
# generated 404 groups
# generated 405 groups
# generated 406 groups
# generated 407 groups
# generated 408 groups
# generated 409 groups
# generated 410 groups
# generated 411 groups
# generated 412 groups
# generated 413 groups
# generated 414 groups
# generated 415 groups
# generated 416 groups
# generated 417 groups
# generated 418 groups
# generated 419 groups
# generated 420 groups
# generated 421 groups
# generated 422 groups
# generated 423 groups
# generated 424 groups
# generated 425 groups
# generated 426 groups
# generated 427 groups
# generated 428 groups
# generated 429 groups
# generated 430 groups
# generated 431 groups
# generated 432 groups
# generated 433 groups
# generated 434 groups
# generated 435 groups
# generated 436 groups
# generated 437 groups
# generated 438 groups
# generated 439 groups
# generated 440 groups
# generated 441 groups
# generated 442 groups
# generated 443 groups
# generated 444 groups
# generated 445 groups
# generated 446 groups
# generated 447 groups
# generated 448 groups
# generated 449 groups
# generated 450 groups
# generated 451 groups
# generated 452 groups
# generated 453 groups
# generated 454 groups
# generated 455 groups
# generated 456 groups
# generated 457 groups
# generated 458 groups
# generated 459 groups
# generated 460 groups
# generated 461 groups
# generated 462 groups
# generated 463 groups
# generated 464 groups
# generated 465 groups
# generated 466 groups
# generated 467 groups
# generated 468 groups
# generated 469 groups
# generated 470 groups
# generated 471 groups
# generated 472 groups
# generated 473 groups
# generated 474 groups
# generated 475 groups
# generated 476 groups
# generated 477 groups
# generated 478 groups
# generated 479 groups
# generated 480 groups
# generated 481 groups
# generated 482 groups
# generated 483 groups
# generated 484 groups
# generated 485 groups
# generated 486 groups
# generated 487 groups
# generated 488 groups
# generated 489 groups
# generated 490 groups
# generated 491 groups
# generated 492 groups
# generated 493 groups
# generated 494 groups
# generated 495 groups
# generated 496 groups
# generated 497 groups
# generated 498 groups
# generated 499 groups
# generated 500 groups
# generated 501 groups
# generated 502 groups
# generated 503 groups
# generated 504 groups
# generated 505 groups
# generated 506 groups
# generated 507 groups
# generated 508 groups
# generated 509 groups
# generated 510 groups
# generated 511 groups
# generated 512 groups
# generated 513 groups
# generated 514 groups
# generated 515 groups
# generated 516 groups
# generated 517 groups
# generated 518 groups
# generated 519 groups
# generated 520 groups
# generated 521 groups
# generated 522 groups
# generated 523 groups
# generated 524 groups
# generated 525 groups
# generated 526 groups
# generated 527 groups
# generated 528 groups
# generated 529 groups
# generated 530 groups
# generated 531 groups
# generated 532 groups
# generated 533 groups
# generated 534 groups
# generated 535 groups
# generated 536 groups
# generated 537 groups
# generated 538 groups
# generated 539 groups
# generated 540 groups
# generated 541 groups
# generated 542 groups
# generated 543 groups
# generated 544 groups
# generated 545 groups
# generated 546 groups
# generated 547 groups
# generated 548 groups
# generated 549 groups
# generated 550 groups
# generated 551 groups
# generated 552 groups
# generated 553 groups
# generated 554 groups
# generated 555 groups
# generated 556 groups
# generated 557 groups
# generated 558 groups
# generated 559 groups
# generated 560 groups
# generated 561 groups
# generated 562 groups
# generated 563 groups
# generated 564 groups
# generated 565 groups
# generated 566 groups
# generated 567 groups
# generated 568 groups
# generated 569 groups
# generated 570 groups
# generated 571 groups
# generated 572 groups
# generated 573 groups
# generated 574 groups
# generated 575 groups
# generated 576 groups
# generated 577 groups
# generated 578 groups
# generated 579 groups
# generated 580 groups
# generated 581 groups
# generated 582 groups
# generated 583 groups
# generated 584 groups
# generated 585 groups
# generated 586 groups
# generated 587 groups
# generated 588 groups
# generated 589 groups
# generated 590 groups
# generated 591 groups
# generated 592 groups
# generated 593 groups
# generated 594 groups
# generated 595 groups
# generated 596 groups
# generated 597 groups
# generated 598 groups
# generated 599 groups
# generated 600 groups
# generated 601 groups
# generated 602 groups
# generated 603 groups
# generated 604 groups
# generated 605 groups
# generated 606 groups
# generated 607 groups
# generated 608 groups
# generated 609 groups
# generated 610 groups
# generated 611 groups
# generated 612 groups
# generated 613 groups
# generated 614 groups
# generated 615 groups
# generated 616 groups
# generated 617 groups
# generated 618 groups
# generated 619 groups
# generated 620 groups
# generated 621 groups
# generated 622 groups
# generated 623 groups
# generated 624 groups
# generated 625 groups
# generated 626 groups
# generated 627 groups
# generated 628 groups
# generated 629 groups
# generated 630 groups
# generated 631 groups
# generated 632 groups
# generated 633 groups
# generated 634 groups
# generated 635 groups
# generated 636 groups
# generated 637 groups
# generated 638 groups
# generated 639 groups
# generated 640 groups
# generated 641 groups
# generated 642 groups
# generated 643 groups
# generated 644 groups
# generated 645 groups
# generated 646 groups
# generated 647 groups
# generated 648 groups
# generated 649 groups
# generated 650 groups
# generated 651 groups
# generated 652 groups
# generated 653 groups
# generated 654 groups
# generated 655 groups
# generated 656 groups
# generated 657 groups
# generated 658 groups
# generated 659 groups
# generated 660 groups
# generated 661 groups
# generated 662 groups
# generated 663 groups
# generated 664 groups
# generated 665 groups
# generated 666 groups
# generated 667 groups
# generated 668 groups
# generated 669 groups
# generated 670 groups
# generated 671 groups
# generated 672 groups
# generated 673 groups
# generated 674 groups
# generated 675 groups
# generated 676 groups
# generated 677 groups
# generated 678 groups
# generated 679 groups
# generated 680 groups
# generated 681 groups
# generated 682 groups
# generated 683 groups
# generated 684 groups
# generated 685 groups
# generated 686 groups
# generated 687 groups
# generated 688 groups
# generated 689 groups
# generated 690 groups
# generated 691 groups
# generated 692 groups
# generated 693 groups
# generated 694 groups
# generated 695 groups
# generated 696 groups
# generated 697 groups
# generated 698 groups
# generated 699 groups
# generated 700 groups
# generated 701 groups
# generated 702 groups
# generated 703 groups
# generated 704 groups
# generated 705 groups
# generated 706 groups
# generated 707 groups
# generated 708 groups
# generated 709 groups
# generated 710 groups
# generated 711 groups
# generated 712 groups
# generated 713 groups
# generated 714 groups
# generated 715 groups
# generated 716 groups
# generated 717 groups
# generated 718 groups
# generated 719 groups
# generated 720 groups
# generated 721 groups
# generated 722 groups
# generated 723 groups
# generated 724 groups
# generated 725 groups
# generated 726 groups
# generated 727 groups
# generated 728 groups
# generated 729 groups
# generated 730 groups
# generated 731 groups
# generated 732 groups
# generated 733 groups
# generated 734 groups
# generated 735 groups
# generated 736 groups
# generated 737 groups
# generated 738 groups
# generated 739 groups
# generated 740 groups
# generated 741 groups
# generated 742 groups
# generated 743 groups
# generated 744 groups
# generated 745 groups
# generated 746 groups
# generated 747 groups
# generated 748 groups
# generated 749 groups
# generated 750 groups
# generated 751 groups
# generated 752 groups
# generated 753 groups
# generated 754 groups
# generated 755 groups
# generated 756 groups
# generated 757 groups
# generated 758 groups
# generated 759 groups
# generated 760 groups
# generated 761 groups
# generated 762 groups
# generated 763 groups
# generated 764 groups
# generated 765 groups
# generated 766 groups
# generated 767 groups
# generated 768 groups
# generated 769 groups
# generated 770 groups
# generated 771 groups
# generated 772 groups
# generated 773 groups
# generated 774 groups
# generated 775 groups
# generated 776 groups
# generated 777 groups
# generated 778 groups
# generated 779 groups
# generated 780 groups
# generated 781 groups
# generated 782 groups
# generated 783 groups
# generated 784 groups
# generated 785 groups
# generated 786 groups
# generated 787 groups
# generated 788 groups
# generated 789 groups
# generated 790 groups
# generated 791 groups
# generated 792 groups
# generated 793 groups
# generated 794 groups
# generated 795 groups
# generated 796 groups
# generated 797 groups
# generated 798 groups
# generated 799 groups
# generated 800 groups

# %%
total_durations = [sum(dataod[key]) for key in dataod]
longest_durations = [max(dataod[key]) for key in dataod]
average_durations = [sum(dataod[key]) / len(dataod[key]) for key in dataod]
fig, axs = plt.subplots(3, 1, figsize=(16, 15))
axs[0].set_title('total duration of all groups')
axs[0].plot(list(dataod.keys()), total_durations, marker='o')
axs[0].set_xlabel('maxDelta')
axs[1].set_title('max duration of all groups')
axs[1].plot(list(dataod.keys()), longest_durations, marker='o')
axs[1].set_xlabel('maxDelta')
axs[2].set_title('average duration of all groups')
axs[2].plot(list(dataod.keys()), average_durations, marker='o')
axs[2].set_xlabel('maxDelta')
# Out:
# Text(0.5, 0, 'maxDelta')

# %%
fig, axs = plt.subplots(3, 1, figsize=(16, 15))
axs[0].set_title('total duration of all groups')
axs[0].plot(list(dataod.keys())[:15], total_durations[:15], marker='o')
axs[0].set_xlabel('maxDelta')
axs[1].set_title('max duration of all groups')
axs[1].plot(list(dataod.keys())[:15], longest_durations[:15], marker='o')
axs[1].set_xlabel('maxDelta')
axs[2].set_title('average duration of all groups')
axs[2].plot(list(dataod.keys())[:15], average_durations[:15], marker='o')
axs[2].set_xlabel('maxDelta')
# Out:
# Text(0.5, 0, 'maxDelta')

# %%
fig, axs = plt.subplots(3, 1, figsize=(16, 15))
axs[0].set_title('total duration of all groups')
axs[0].plot(list(dataod.keys())[660:], total_durations[660:], marker='o')
axs[0].set_xlabel('maxDelta')
axs[1].set_title('max duration of all groups')
axs[1].plot(list(dataod.keys())[660:], longest_durations[660:], marker='o')
axs[1].set_xlabel('maxDelta')
axs[2].set_title('average duration of all groups')
axs[2].plot(list(dataod.keys())[660:], average_durations[660:], marker='o')
axs[2].set_xlabel('maxDelta')
# Out:
# Text(0.5, 0, 'maxDelta')
