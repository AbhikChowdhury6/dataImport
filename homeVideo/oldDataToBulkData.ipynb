# %%
# I'll read in all of the frame metadata, and just save the the indexes as new df's to the right location

# dude I think that I could just flatten all the video files and move them

# I'd do a smilar check to see if I need to split

# %%
import os
import pandas as pd

deskCamInfo = ["abhik", "deskCam", "abhik", "pcCam-webcam", "mp4", "vidCap"]
bathroomCamInfo = ["abhik", "bathroomCam", "abhik", "pcCam-webcam", "mp4", "vidCap"]

deskCamLocation = "/home/chowder/Documents/oldworkingData/homeVideo/deskCam/frameMetaData/"
for i, fn in enumerate(sorted(os.listdir(deskCamLocation))):
    if i == 0:
        deskCamDf = pd.read_parquet(deskCamLocation + fn)
    else:
        deskCamDf = pd.concat([deskCamDf, pd.read_parquet(deskCamLocation + fn)])

deskCamDf = deskCamDf.drop(columns=deskCamDf.columns).sort_index()

# now we could save the deskCamDf to the right spot
# but first we're going to flatten the deskcam directory
# find deskCam/ -type f -exec cp -n {} dc/ \;
deskCamVidLocation = "/home/chowder/Documents/videoData/dc/"

# %%
bathroomCamLocation = "/home/chowder/Documents/oldworkingData/homeVideo/bathroomCam/frameMetaData/"
for i, fn in enumerate(sorted(os.listdir(bathroomCamLocation))):
    if i == 0:
        bathroomCamDf = pd.read_parquet(bathroomCamLocation + fn)
    else:
        bathroomCamDf = pd.concat([bathroomCamDf, pd.read_parquet(bathroomCamLocation + fn)])

bathroomCamDf = bathroomCamDf.drop(columns=bathroomCamDf.columns).sort_index()
#mkdir bc
# find bathroomCam/ -type f -exec cp -n {} bc/ \;

bathroomCamVidLocation = "/home/chowder/Documents/videoData/bc/"

# %%
from datetime import datetime, timedelta
from zoneinfo import ZoneInfo
import pandas as pd
import os
import sys
import subprocess
import cv2
import shutil

# %%
def getRepoPath():
    cwd = os.getcwd()
    delimiter = "\\" if "\\" in cwd else "/"
    repoPath = delimiter.join(cwd.split(delimiter)[:cwd.split(delimiter).index("dataImport")]) + delimiter
    return repoPath
repoPath = getRepoPath()

# %%
def geBulkLocation(time, responsiblePartyName, instanceName, developingPartyName, deviceName, dataType, dataSource):
    dataFolderName = "_".join([responsiblePartyName, instanceName, developingPartyName, deviceName, dataType, dataSource]) + "/"
    dataFolderName += time.strftime("%Y") + "/" + time.strftime("%m-%d") + "/"
    return repoPath + "bulkData/" + dataFolderName

def fnString_to_dt(fn_string):
    fn_string = fn_string[:17] + ',' + fn_string[18:]
    return datetime.fromisoformat(fn_string.replace(",", "."))

def dt_to_fnString(dt):
    return dt.astimezone(ZoneInfo("UTC")).strftime('%Y-%m-%dT%H%M%S,%f%z')

def splitVidopencv(input_file_location, boundary_indexes, output_paths):
    cap = cv2.VideoCapture(input_file_location)
    fps = cap.get(cv2.CAP_PROP_FPS)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fourcc = cv2.VideoWriter_fourcc(*'avc1')
    
    for i, (start_frame, end_frame) in enumerate(boundary_indexes):
        cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
        out = cv2.VideoWriter(output_paths[i], fourcc, fps, (width, height))

        for frame_idx in range(start_frame, end_frame):
            ret, frame = cap.read()
            if not ret:
                break
            out.write(frame)

        out.release()
        print(f"Saved: {output_paths[i]}")

    cap.release()

# %%
# honestly we could make a function that takes in a directory containing a bunch of mp4s and splits them if needed
def copyAndSplitMp4(folderPath, timeDF, camDetails):
    vidFileNames = sorted(os.listdir(folderPath))
    for fileName in vidFileNames:
        startTime = fnString_to_dt(fileName.split("_")[-2]).astimezone(ZoneInfo("UTC"))
        endTime = fnString_to_dt(fileName.split("_")[-1][:-4]).astimezone(ZoneInfo("UTC"))
        
        if startTime.day == endTime.day:
            newFileName = dt_to_fnString(startTime) + "_" + dt_to_fnString(endTime) + ".mp4"
            source = folderPath + fileName
            destination = geBulkLocation(startTime, *camDetails)
            if not os.path.exists(destination):
                print("made directory " + destination)
                os.makedirs(destination)
            shutil.copy2(source, destination  + newFileName)
            continue
        
        # the file contains more than one day of data
        frameTimes = timeDF[startTime:endTime].copy()
        frameTimes['date'] = frameTimes.index.normalize()
        boundaries = frameTimes.groupby('date').apply(lambda x: (x.index[0], x.index[-1]), include_groups=False)
        index_boundaries = [(frameTimes.index.get_loc(start), frameTimes.index.get_loc(end))
                                for day, (start, end) in boundaries.items()]
        
        output_paths = [geBulkLocation(x[0], *camDetails) + 
                        dt_to_fnString(x[0]) + "_" + dt_to_fnString(x[1]) + ".mp4" 
                        for x in boundaries]

        splitVidopencv(folderPath + fileName  + ".mp4", index_boundaries, output_paths)

# %%
copyAndSplitMp4(deskCamVidLocation, deskCamDf, deskCamInfo)
# Out:
# made directory /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-11/
# Saved: /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-11/2024-11-11T233021,700087+0000_2024-11-12T001151,100085+0000.mp4
# made directory /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-12/
# Saved: /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-12/2024-11-12T235701,100096+0000_2024-11-13T000001,000089+0000.mp4
# made directory /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-13/
# Saved: /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-13/2024-11-13T231630,000158+0000_2024-11-14T043836,400084+0000.mp4
# made directory /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-14/
# made directory /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-15/
# Saved: /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-15/2024-11-15T213245,000161+0000_2024-11-16T000215,900095+0000.mp4
# made directory /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-16/
# Saved: /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-16/2024-11-16T221826,100156+0000_2024-11-17T022831,500159+0000.mp4
# made directory /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-17/
# Saved: /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-17/2024-11-17T234523,100162+0000_2024-11-18T000217,400159+0000.mp4
# made directory /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-18/
# Saved: /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-18/2024-11-18T235630,007494+0000_2024-11-19T001737,600157+0000.mp4
# made directory /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-19/
# Saved: /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-19/2024-11-19T235854,100155+0000_2024-11-20T000353,200165+0000.mp4
# made directory /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-20/
# Saved: /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-20/2024-11-20T230415,000195+0000_2024-11-21T051930,000274+0000.mp4
# made directory /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-21/
# Saved: /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-21/2024-11-21T235700,500162+0000_2024-11-22T000000,500170+0000.mp4
# made directory /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-22/
# Saved: /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-22/2024-11-22T231536,300165+0000_2024-11-23T005457,500158+0000.mp4
# made directory /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-23/
# Saved: /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-23/2024-11-23T235807,200177+0000_2024-11-24T000107,100164+0000.mp4
# made directory /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-24/
# Saved: /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-24/2024-11-24T235851,900160+0000_2024-11-25T000151,800190+0000.mp4
# made directory /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-25/
# Saved: /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-25/2024-11-25T234841,400173+0000_2024-11-26T010013,900159+0000.mp4
# made directory /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-26/
# Saved: /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-26/2024-11-26T235811,000160+0000_2024-11-27T000110,900161+0000.mp4
# made directory /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-27/
# Saved: /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-27/2024-11-27T235722,400159+0000_2024-11-28T051630,000279+0000.mp4
# made directory /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-28/
# Saved: /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-28/2024-11-28T215415,000305+0000_2024-11-29T010330,000282+0000.mp4
# made directory /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-29/
# Saved: /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-29/2024-11-29T235746,200155+0000_2024-11-30T030945,000279+0000.mp4
# made directory /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-30/
# Saved: /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/11-30/2024-11-30T235644,400165+0000_2024-12-01T002120,900165+0000.mp4
# made directory /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/12-01/
# Saved: /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/12-01/2024-12-01T232019,100160+0000_2024-12-02T002210,500155+0000.mp4
# made directory /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/12-02/
# Saved: /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/12-02/2024-12-02T235922,300155+0000_2024-12-03T000222,200156+0000.mp4
# made directory /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/12-03/
# Saved: /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/12-03/2024-12-03T235045,000206+0000_2024-12-04T042739,700160+0000.mp4
# made directory /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/12-04/
# Saved: /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/12-04/2024-12-04T210230,000216+0000_2024-12-05T011051,200156+0000.mp4
# made directory /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/12-05/
# Saved: /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/12-05/2024-12-05T235629,300160+0000_2024-12-06T000058,800161+0000.mp4
# made directory /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/12-06/
# Saved: /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/12-06/2024-12-06T235827,900159+0000_2024-12-07T000242,600154+0000.mp4
# made directory /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/12-07/
# Saved: /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/12-07/2024-12-07T235850,400163+0000_2024-12-08T000250,000155+0000.mp4
# made directory /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/12-08/
# Saved: /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/12-08/2024-12-08T234118,100156+0000_2024-12-09T001421,100167+0000.mp4
# made directory /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/12-09/
# Saved: /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/12-09/2024-12-09T214630,000179+0000_2024-12-10T004449,500155+0000.mp4
# made directory /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/12-10/
# Saved: /home/chowder/Documents/bulkData/abhik_deskCam_abhik_pcCam-webcam_mp4_vidCap/2024/12
00:00
# reading and combining to see if there's any new data
# hashes still don't match
# saved to a file named 2024-11-16T163115,600158+0000_2024-11-19T014824,200161+0000_158eb1ff_.parquet.gzip
# the hashes don't match for start time 2024-11-19 01:48:24.200161+00:00 to end time 2024-11-20 15:33:39.700157+00:00
# reading and combining to see if there's any new data
# hashes still don't match
# saved to a file named 2024-11-19T014824,200161+0000_2024-11-20T153339,700157+0000_6f373183_.parquet.gzip
# the hashes don't match for start time 2024-11-20 15:33:39.700157+00:00 to end time 2024-11-22 22:44:52.200149+00:00
# reading and combining to see if there's any new data
# hashes still don't match
# saved to a file named 2024-11-20T153339,700157+0000_2024-11-22T224452,200149+0000_91dbfa46_.parquet.gzip
# the hashes don't match for start time 2024-11-22 22:44:52.200149+00:00 to end time 2024-11-24 05:25:57.700163+00:00
# reading and combining to see if there's any new data
# hashes still don't match
# saved to a file named 2024-11-22T224452,200149+0000_2024-11-24T052557,700163+0000_9d28fb01_.parquet.gzip
# the hashes don't match for start time 2024-11-24 05:25:57.700163+00:00 to end time 2024-11-25 04:13:22.600171+00:00
# reading and combining to see if there's any new data
# hashes still don't match
# saved to a file named 2024-11-24T052557,700163+0000_2024-11-25T041322,600171+0000_8c45ad1a_.parquet.gzip
# the hashes don't match for start time 2024-11-25 04:13:22.600171+00:00 to end time 2024-11-26 18:07:50.000160+00:00
# reading and combining to see if there's any new data
# hashes still don't match
# saved to a file named 2024-11-25T041322,600171+0000_2024-11-26T180750,000160+0000_fc275313_.parquet.gzip
# the hashes don't match for start time 2024-11-26 18:07:50.000160+00:00 to end time 2024-11-30 16:35:18.300160+00:00
# reading and combining to see if there's any new data
# hashes still don't match
# saved to a file named 2024-11-26T180750,000160+0000_2024-11-30T163518,300160+0000_f75435dd_.parquet.gzip
# the hashes don't match for start time 2024-11-30 16:35:18.300160+00:00 to end time 2024-12-02 01:08:21.900159+00:00
# reading and combining to see if there's any new data
# hashes still don't match
# saved to a file named 2024-11-30T163518,300160+0000_2024-12-02T010821,900159+0000_fb141e6a_.parquet.gzip
# the hashes don't match for start time 2024-12-02 01:08:21.900159+00:00 to end time 2024-12-02 21:59:37.400161+00:00
# reading and combining to see if there's any new data
# hashes still don't match
# saved to a file named 2024-12-02T010821,900159+0000_2024-12-02T215937,400161+0000_b4ed87ca_.parquet.gzip
# the hashes don't match for start time 2024-12-02 21:59:37.400161+00:00 to end time 2024-12-04 13:52:45.100118+00:00
# reading and combining to see if there's any new data
# hashes still don't match
# saved to a file named 2024-12-02T215937,400161+0000_2024-12-04T135245,100118+0000_7d31e656_.parquet.gzip
# the hashes don't match for start time 2024-12-04 13:52:45.100118+00:00 to end time 2024-12-05 20:07:40.600165+00:00
# reading and combining to see if there's any new data
# hashes still don't match
# saved to a file named 2024-12-04T135245,100118+0000_2024-12-05T200740,600165+0000_7f449b63_.parquet.gzip
# the hashes don't match for start time 2024-12-05 20:07:40.600165+00:00 to end time 2024-12-07 02:17:59.400154+00:00
# reading and combining to see if there's any new data
# hashes still don't match
# saved to a file named 2024-12-05T200740,600165+0000_2024-12-07T021759,400154+0000_4e563774_.parquet.gzip
# the hashes don't match for start time 2024-12-07 02:17:59.400154+00:00 to end time 2024-12-08 01:57:19.200154+00:00
# reading and combining to see if there's any new data
# hashes still don't match
# saved to a file named 2024-12-07T021759,400154+0000_2024-12-08T015719,200154+0000_3c1d28ac_.parquet.gzip
# the hashes don't match for start time 2024-12-08 01:57:19.200154+00:00 to end time 2024-12-09 00:59:39.300159+00:00
# reading and combining to see if there's any new data
# hashes still don't match
# saved to a file named 2024-12-08T015719,200154+0000_2024-12-09T005939,300159+0000_07d2a863_.parquet.gzip
# the hashes don't match for start time 2024-12-09 00:59:39.300159+00:00 to end time 2024-12-09 20:08:01.100167+00:00
# reading and combining to see if there's any new data
# hashes still don't match
# saved to a file named 2024-12-09T005939,300159+0000_2024-12-09T200801,100167+0000_a40aae78_.parquet.gzip
# hashes match for 2024-12-09T200801,100167+0000_2024-12-10T185234,900161+0000_77c83afa_.parquet.gzip
# the hashes don't match for start time 2024-12-10 18:52:34.900161+00:00 to end time 2024-12-12 05:05:29.400160+00:00
# reading and combining to see if there's any new data
# hashes match now
# nothing to add
# nothing to add
# nothing to add
# nothing to add
# nothing to add
# nothing to add
# nothing to add
# nothing to add
# nothing to add
# nothing to add
# nothing to add
# nothing to add
# nothing to add
# nothing to add
# nothing to add
# nothing to add
# nothing to add
# nothing to add
# nothing to add
# nothing to add
# nothing to add
# nothing to add
# nothing to add
# nothing to add
# nothing to add
# nothing to add

# %%
import importlib
importlib.reload(rwWorkingTSDf)
# Out:
# <module 'rwWorkingTSDf' from '/home/chowder/Documents/dataImport/rwWorkingTSDf.py'>
